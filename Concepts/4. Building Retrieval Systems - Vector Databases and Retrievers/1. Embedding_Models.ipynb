# %% [markdown]
# ## Setup Environments

# %%
# %run Setup.ipynb

# %% [markdown]
# ## Embedding models
#
# The Embeddings class is a class designed for interfacing with text embedding models. There are lots of embedding model providers (OpenAI, Cohere, Hugging Face, etc) - this class is designed to provide a standard interface for all of them.
#
# Embeddings create a vector representation of a piece of text. This is useful because it means we can think about text in the vector space, and do things like semantic search where we look for pieces of text that are most similar in the vector space.
#
# The base Embeddings class in LangChain provides two methods: one for embedding documents and one for embedding a query. The former takes as input multiple texts, while the latter takes a single text. The reason for having these as two separate methods is that some embedding providers have different embedding methods for documents (to be searched over) vs queries (the search query itself).

# %%
docs = [
    "cats eat and sleep",
    "dogs eat and bark",
    "cars drive fast",
    "vehicles include trucks and cars"
]

# %% [markdown]
# Embeddings create a vector representation of a piece of text. This is useful because it means we can think about text in the vector space, and do things like semantic search where we look for pieces of text that are most similar in the vector space.
#
# The base Embeddings class in LangChain provides two methods: one for embedding documents and one for embedding a query. The former, `.embed_documents`, takes as input multiple texts, while the latter, `.embed_query`, takes a single text. The reason for having these as two separate methods is that some embedding providers have different embedding methods for documents (to be searched over) vs queries (the search query itself).
#
# - `.embed_query`  will return a list of floats,
# - `.embed_documents` returns a list of lists of floats.

# %% [markdown]
# ### Open AI Embedding Models
#
# LangChain enables us to access Open AI embedding models which include the newest models: a smaller and highly efficient `text-embedding-3-small` model, and a larger and more powerful `text-embedding-3-large` model.

# %%
from pprint import pprint

# %% [markdown]
# ## OpenAI's `text-embedding-3-small` Model Specifications
#
# The **1536 dimensions** is the default output size for OpenAI's `text-embedding-3-small` model. This is a design choice made by OpenAI when they created this embedding model.
#
# ---
#
# ### Key Points About the 1536 Dimension Size
#
# #### 1. Model Architecture Design
# - OpenAI designed `text-embedding-3-small` to output **1536-dimensional vectors** by default.
# - This size balances **performance** and **computational efficiency**.
# - It is smaller than the larger `text-embedding-3-large` model, which outputs **3072 dimensions**.
#
# #### 2. Why 1536 Specifically?
# - **Powers of 2:** 1536 = 3 × 512, where 512 is 2⁹ (a common size in neural networks).
# - **Computational Efficiency:** This size works well with modern GPU architectures.
# - **Information Capacity:** 1536 dimensions provide enough capacity to capture semantic meaning effectively.

# %%
from langchain_openai import OpenAIEmbeddings

# details here: https://openai.com/blog/new-embedding-models-and-api-updates
openai_embed_model = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
embeddings = openai_embed_model.embed_documents(docs)

# %%
print(f"The length of the embeddings is {len(embeddings)}")
# Out:
# The length of the embeddings is 4

# %%
embeddings
# Out:
# [[-0.014177093282341957, -0.004976172931492329, -0.009036445990204811, 0.01158419530838728, 0.020240090787410736, 0.026702988892793655, 0.023839188739657402, 0.035087984055280685, -0.0050664725713431835, 0.0032314485870301723, 0.05015517771244049, 0.0012254994362592697, 0.03108898550271988, 0.046955980360507965, 0.0034668734297156334, 0.01676999218761921, 0.008081846870481968, 0.012242094613611698, -0.006998247001320124, 0.03550078347325325, 0.0372035838663578, -0.02899918705224991, 0.03212098404765129, -0.03583618253469467, -0.029721586033701897, 0.054747574031353, -0.00852044578641653, 0.03351418673992157, 0.012125995010137558, -0.029308786615729332, 0.02483248896896839, -0.040686581283807755, -0.01138424500823021, -0.04086718335747719, 0.011397144757211208, 0.023078089579939842, 0.020214291289448738, -0.031475987285375595, -0.0067724972032010555, 0.013286993838846684, -0.009333145804703236, 0.01478339359164238, 0.021813889965415, -0.009494395926594734, -0.009068695828318596, -0.022497590631246567, -0.029050787910819054, -0.0066499472595751286, 0.05448957532644272, 0.02174939028918743, -0.0013940056087449193, -0.023245789110660553, 0.002757373731583357, -0.02141399122774601, -0.0025880613829940557, 0.012932244688272476, 0.024316489696502686, 0.028457388281822205, -0.00443437322974205, 0.008855845779180527, 0.011577744968235493, 0.056295573711395264, 0.07048556953668594, -0.0035700735170394182, 0.0026267613284289837, 0.005559897515922785, 0.02217509038746357, -0.040428582578897476, -0.014241593889892101, -0.028096187859773636, -0.01372559368610382, -0.010571544989943504, -0.0241358894854784, 0.055211976170539856, 0.04909737780690193, 0.010107145644724369, -0.01989179104566574, 0.004847172647714615, 0.03965458273887634, 0.07631636410951614, -0.00423442292958498, 0.040557581931352615, 0.02287168987095356, -0.027863986790180206, -0.01079084537923336, -0.03867418318986893, -0.024522889405488968, -0.016202392056584358, -0.00680474704131484, 0.028225187212228775, 0.04711077734827995, -0.013106394559144974, -0.05830797553062439, -0.020639991387724876, 0.018717892467975616, 0.0177374929189682, -0.011164944618940353, -0.02576128952205181, 0.010184545069932938, 0.0058791725896298885, 0.03039238601922989, -0.029721586033701897, -0.021891290321946144, 0.015854092314839363, 0.00765614677220583, 0.01922099106013775, 0.01885979250073433, -0.027786588296294212, 0.030056986957788467, -0.01297739427536726, -0.02251048944890499, -0.04401478171348572, 0.005085822660475969, -0.015041393227875233, -0.00584369758144021, -0.024290690198540688, 0.04922637715935707, -0.0027025488670915365, -0.02462608925998211, -0.010848895646631718, 0.052993178367614746, 0.07043396681547165, -0.031114786863327026, -0.043111782521009445, -0.02392948977649212, -0.013164443895220757, -0.008778446353971958, -0.025374289602041245, -0.04447918012738228, 0.011364894919097424, -0.011539044789969921, 0.010494145564734936, 0.042182981967926025, -0.04269897937774658, -0.02625148929655552, 0.007681946735829115, -0.028689587488770485, 0.005301897879689932, -0.042647380381822586, 0.05433477461338043, 0.03841618448495865, -0.027141587808728218, -0.004656897857785225, 0.025967689231038094, -0.024084288626909256, -0.03882898390293121, 0.01531229354441166, 0.040918782353401184, -0.030211785808205605, -0.057327575981616974, -0.011429394595324993, 0.034623585641384125, -0.02783818729221821, 0.028844386339187622, -0.03157918527722359, 0.036016784608364105, 0.04641417786478996, -0.058720774948596954, -0.021568790078163147, 0.03542338311672211, 0.03599098324775696, -0.058359574526548386, 0.013261194340884686, 0.027863986790180206, -0.025051789358258247, 0.01286129467189312, -0.03849358484148979, 0.023090990260243416, -0.0337463840842247, -0.017595592886209488, -0.004476298112422228, -0.030547186732292175, -0.028612187132239342, -0.02608378790318966, -0.010765044949948788, -0.0088816462084651, 0.005611497443169355, 0.027760786935687065, -0.02101409062743187, -0.013712693937122822, 0.0247292 ...

# %%
# Loop through each embedding vector in the embeddings list
for embedding in embeddings:
    # Print the length of the current embedding vector
    # This shows how many dimensions (features) each embedding has
    print(len(embedding))
# Out:
# 1536
# 1536
# 1536
# 1536

# %% [markdown]
# #### Customizable Dimensions
# You can actually change the output dimensions using OpenAI's embedding models:

# %%
from langchain_openai import OpenAIEmbeddings

# Default 1536 dimensions
openai_embed_default = OpenAIEmbeddings(model="text-embedding-3-small")

# Custom dimensions (can be reduced for efficiency)
openai_embed_custom = OpenAIEmbeddings(
    model="text-embedding-3-small",
    dimensions=512  # Reduce to 512 dimensions
)

# %%
embeddings_custom = openai_embed_custom.embed_documents(docs)
embeddings_custom
# Out:
# [[-0.0207798033952713, -0.007293730042874813, -0.013244997709989548, 0.016979312524199486, 0.02966652624309063, 0.03913939371705055, 0.034941837191581726, 0.051429543644189835, -0.007426085416227579, 0.004736433736979961, 0.07351399213075638, 0.0017962524434551597, 0.045568086206912994, 0.06882482767105103, 0.00508150365203619, 0.024580296128988266, 0.011845812201499939, 0.017943615093827248, -0.010257546789944172, 0.05203459411859512, 0.054530441761016846, -0.04250500351190567, 0.04708072170615196, -0.05252620205283165, -0.0435638464987278, 0.08024521172046661, -0.012488680891692638, 0.049122776836156845, 0.017773443832993507, -0.04295879229903221, 0.036397743970155716, -0.05963557958602905, -0.01668624021112919, -0.05990029126405716, 0.016705147922039032, 0.03382626920938492, 0.029628710821270943, -0.046135324984788895, -0.009926658123731613, 0.01947515830397606, -0.01367987971752882, 0.02166847698390484, 0.03197329118847847, -0.013916228897869587, -0.013292267918586731, -0.03297541290521622, -0.042580634355545044, -0.009747033007442951, 0.07986705005168915, 0.0318787544965744, -0.0020432372111827135, -0.03407207131385803, 0.004041567910462618, -0.031387146562337875, -0.003793401410803199, 0.018955189734697342, 0.03564142808318138, 0.04171087220311165, -0.0064995973370969296, 0.012980286963284016, 0.01696985773742199, 0.08251415938138962, 0.10331287235021591, -0.0052327667362987995, 0.00385012524202466, 0.008149313740432262, 0.03250271454453468, -0.059257421642541885, -0.020874343812465668, -0.041181448847055435, -0.020118026062846184, -0.015495040453970432, -0.035376716405153275, 0.08092589676380157, 0.07196354120969772, 0.014814355410635471, -0.02915601246058941, 0.007104651071131229, 0.058122944086790085, 0.11185925453901291, -0.006206524558365345, 0.05944649875164032, 0.033523742109537125, -0.040841106325387955, -0.015816474333405495, -0.05668594315648079, -0.035943955183029175, -0.023748347535729408, -0.009973927401006222, 0.04137052968144417, 0.06905172020196915, -0.019210446625947952, -0.08546379953622818, -0.030252672731876373, 0.027435392141342163, 0.025998389348387718, -0.01636480540037155, -0.037759117782115936, 0.014927802607417107, 0.008617284707725048, 0.04454705864191055, -0.0435638464987278, -0.03208674117922783, 0.023237833753228188, 0.011221850290894508, 0.028172800317406654, 0.02764337882399559, -0.040727660059928894, 0.044055454432964325, -0.01902136765420437, -0.03299431875348091, -0.06451382488012314, 0.007454447448253632, -0.022046634927392006, -0.008565288037061691, -0.035603612661361694, 0.07215262204408646, -0.003961209207773209, -0.03609522059559822, -0.015901559963822365, 0.07767373323440552, 0.10323724150657654, -0.04560590162873268, -0.0631902664899826, -0.03507419303059578, -0.019295532256364822, -0.01286683976650238, -0.037191879004240036, -0.0651945099234581, 0.01665787771344185, -0.01691313460469246, 0.015381593257188797, 0.06182889640331268, -0.06258521229028702, -0.038477618247270584, 0.01125966664403677, -0.04205121472477913, 0.0077711548656225204, -0.06250958144664764, 0.07964015752077103, 0.05630778521299362, -0.039782263338565826, -0.0068257590755820274, 0.03806164115667343, -0.0353010855615139, -0.05691283941268921, 0.022443700581789017, 0.05997592210769653, -0.044282346963882446, -0.08402679860591888, -0.016752416267991066, 0.050748858600854874, -0.04080329090356827, 0.04227810725569725, -0.04628658667206764, 0.052790913730859756, 0.0680306926369667, -0.08606885373592377, -0.031614042818546295, 0.05192114785313606, 0.05275309830904007, -0.08553943037986755, 0.019437341019511223, 0.040841106325387955, -0.0367191806435585, 0.01885119639337063, -0.05642123147845268, 0.03384517505764961, -0.049463119357824326, -0.02579040266573429, -0.006561048328876495, -0.04477395489811897, -0.04193776473402977, -0.03823181241750717, -0.015778658911585808, -0.013018103316426277, 0.00822494551539421, 0.04068984463810921, -0.03080100193619728, -0.02009911835193634, 0.03624648228287697, 0.0578582361340522 ...

# %%
# Loop through each embedding vector in the embeddings list
for embedding in embeddings_custom:
    # Print the length of the current embedding vector
    # This shows how many dimensions (features) each embedding has
    print(len(embedding))
# Out:
# 512
# 512
# 512
# 512

# %% [markdown]
# Embedding Model Dimension Comparison:
# - text-embedding-3-small: 1536 dimensions (default)
# - text-embedding-3-large: 3072 dimensions
# - text-embedding-ada-002: 1536 dimensions
# - Sentence Transformers: Varies (e.g., 384, 768, 1024)

# %% [markdown]
# # Higher dimensions (1536+)
# - ✅ Better semantic representation
# - ✅ More nuanced understanding
# - ❌ More storage space
# - ❌ Slower similarity computations
#
# # Lower dimensions (256-512)
# - ✅ Faster computations
# - ✅ Less storage needed
# - ❌ Potential loss of semantic detail

# %%
len(embeddings[0])
# Out:
# 1536

# %%
docs
# Out:
# ['cats eat and sleep', 'dogs eat and bark', 'cars drive fast', 'vehicles include trucks and cars']

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute the cosine similarity matrix between all pairs of document embeddings.
# The resulting sim_matrix is a square matrix where each entry [i, j] represents
# the similarity between document i and document j. Values range from -1 (opposite)
# to 1 (identical), with 1s on the diagonal (each document is identical to itself).
sim_matrix = cosine_similarity(embeddings)
sim_matrix  # Shows how similar each document is to every other document.
# Out:
# array([[1.        , 0.6126697 , 0.20352739, 0.19823333],
#        [0.6126697 , 1.        , 0.26190051, 0.2003429 ],
#        [0.20352739, 0.26190051, 1.        , 0.39909568],
#        [0.19823333, 0.2003429 , 0.39909568, 1.        ]])

# %% [markdown]
# ## Open Source Embedding Models on HuggingFace
#
# `langchain-huggingface` integrates seamlessly with LangChain, providing an efficient and effective way to utilize Hugging Face models within the LangChain ecosystem.
#
# `HuggingFaceEmbeddings`uses `sentence-transformers` embeddings. It computes the embedding locally, using your computer resources and allows you to access open or open source embedding LLMs hosted on HuggingFace.

# %%
# !pip install -qq langchain_huggingface

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# check out model details here: https://huggingface.co/mixedbread-ai/mxbai-embed-large-v1
model_name = "mixedbread-ai/mxbai-embed-large-v1"

hf_embeddings = HuggingFaceEmbeddings(
    model_name=model_name,
)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/266 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]

# %%
embeddings = hf_embeddings.embed_documents(docs)

# %%
len(embeddings)
# Out:
# 4

# %%
len(embeddings[0])
# Out:
# 1024

# %%
docs
# Out:
# ['cats eat and sleep', 'dogs eat and bark', 'cars drive fast', 'vehicles include trucks and cars']

# %%
sim_matrix = cosine_similarity(embeddings)
sim_matrix
# Out:
# array([[1.        , 0.52515984, 0.34221797, 0.3369172 ],
#        [0.52515984, 1.        , 0.31728526, 0.33082526],
#        [0.34221797, 0.31728526, 1.        , 0.72253285],
#        [0.3369172 , 0.33082526, 0.72253285, 1.        ]])

# %% [markdown]
# ## Build a small search engine!

# %% [markdown]
# ### Load Knowledgebase documents

# %% [markdown]
# We have 10 Document in our Knowledge Base

# %%
documents = [
    'Quantum mechanics describes the behavior of very small particles.',
    'Photosynthesis is the process by which green plants make food using sunlight.',
    "Shakespeare's plays are a testament to English literature.",
    'Artificial Intelligence aims to create machines that can think and learn.',
    'The pyramids of Egypt are historical monuments that have stood for thousands of years.',
    'Biology is the study of living organisms and their interactions with the environment.',
    'Music therapy can aid in the mental well-being of individuals.',
    'The Milky Way is just one of billions of galaxies in the universe.',
    'Economic theories help understand the distribution of resources in society.',
    'Yoga is an ancient practice that involves physical postures and meditation.'
]

# %%
len(documents)
# Out:
# 10

# %%
### Get document embeddings
document_embeddings = openai_embed_model.embed_documents(documents)

# %%
document_embeddings
# Out:
# [[-0.06414780765771866, 0.015736594796180725, -0.04284387081861496, 0.018375450745224953, -0.0320095419883728, -0.016036951914429665, -0.021582841873168945, 0.0713563933968544, -0.03402622789144516, 0.03788796812295914, -0.012314663268625736, 0.0005883121048100293, -0.04827176034450531, 0.020145416259765625, 0.019394520670175552, 0.02379261516034603, 0.0025879028253257275, -0.01640167273581028, 0.05260549485683441, 0.03949702903628349, -0.01271156407892704, -0.046598341315984726, 0.031237194314599037, 0.010469608940184116, 0.012958286330103874, -0.030786657705903053, 0.027825988829135895, 0.01542550977319479, 0.037072714418172836, 0.026924915611743927, 0.07234328240156174, -0.029070327058434486, -0.009670442901551723, -0.05269131064414978, -0.06307510286569595, 0.011102505028247833, -0.0005903234123252332, -0.04509655386209488, 0.012893923558294773, 0.0005923347198404372, -0.014470801688730717, -0.047284871339797974, -0.053549475967884064, 0.021271755918860435, 0.005497617181390524, 0.0030277122277766466, -0.02737545222043991, -0.043616220355033875, -0.017978549003601074, 0.014342077076435089, -0.019190706312656403, -0.005317938979715109, 0.022290827706456184, 0.007004769053310156, -0.011746129021048546, -0.00581942917779088, 0.035506561398506165, 0.02061740681529045, 0.03788796812295914, -0.0004662918217945844, -0.0044946372509002686, -0.011692493222653866, -0.04870084300637245, 0.07281526923179626, -0.032545894384384155, -0.0011967374011874199, 0.012818834744393826, -0.011510133743286133, -0.004727950785309076, 0.007766390219330788, 0.007723481860011816, -0.0018772351322695613, -0.02716091088950634, 0.013398095965385437, 0.016348036006093025, -0.01214302983134985, -0.07079858332872391, -0.006977951154112816, -0.011960670351982117, 0.06719429045915604, -0.024736596271395683, -0.05762575566768646, 0.02746126987040043, -0.010458881966769695, -0.07736354321241379, 0.016884390264749527, 0.01989869214594364, -0.010625150986015797, -0.030786657705903053, -0.004210370127111673, 0.014041719026863575, 0.03713707625865936, -0.019802149385213852, 0.000297675869660452, 0.035721104592084885, -0.01256138551980257, 0.04737069085240364, -0.02181883715093136, -0.020145416259765625, -0.013548274524509907, -0.021604295819997787, 0.0068116821348667145, 0.0025342674925923347, -0.04142789915204048, 0.030593570321798325, -0.010748512111604214, -0.06251729279756546, 0.008839095942676067, -0.0210250336676836, 0.04271514713764191, 0.03228844702243805, -0.007535758428275585, -0.04007628932595253, 0.0013864722568541765, -0.044839102774858475, -0.018933257088065147, 0.01420262549072504, 0.051318246871232986, -0.0023478849325329065, 0.02174374647438526, -0.04254351183772087, 0.011081051081418991, 0.006731228902935982, 0.005111443344503641, 0.020317047834396362, -0.00671513844281435, 0.03198808804154396, -0.01732419990003109, -0.013955902308225632, 0.0765053778886795, 0.008222290314733982, 0.0251013170927763, -0.025144224986433983, -0.03630036488175392, -0.017066748812794685, -0.038381412625312805, 0.04029083251953125, 0.0041620987467467785, 0.008774733170866966, -0.017785461619496346, 0.032545894384384155, -0.03969011455774307, 0.0596853531897068, 0.020424319431185722, -0.005771157331764698, 0.005264303646981716, 0.002240614267066121, 0.028426704928278923, 0.03557092323899269, -0.04471037909388542, -0.0133659141138196, -0.029585227370262146, -0.03713707625865936, 0.03252444043755531, 0.03125864639878273, -0.014009538106620312, 0.0272681824862957, 0.025272948667407036, -0.02082121931016445, 0.0023237490095198154, 0.026367109268903732, 0.010233613662421703, -0.0381239652633667, -0.03600000590085983, -0.003990465775132179, -0.02336353249847889, -0.003561383346095681, 0.011123958975076675, 0.0001252048823516816, -0.033060792833566666, 0.005626342259347439, 0.011381409130990505, 0.031022652983665466, 0.014030992053449154, 0.007551848888397217, 0.00653277849778533, -0.014374257996678352, -0.03488439321517944, -0.007525031454861164, 0.010807511396706104, 0.03522 ...

# %% [markdown]
# ### Let's try to find the most similar document for one query

# %%
new_text = 'What is AI?'
new_text
# Out:
# 'What is AI?'

# %%
query_embedding = openai_embed_model.embed_query(new_text)

# %%
len(query_embedding)
# Out:
# 1536

# %% [markdown]
# Query vs. Documents Similarity Analysis
#
# - Comparing one query embedding: *"What is AI?"*
# - Against 10 document embeddings from the knowledge base
#
# - Objective: Find the document most similar to the query using cosine similarity

# %%
# Compute the cosine similarity between the query embedding and each document embedding
cosine_similarities = cosine_similarity([query_embedding], document_embeddings)
cosine_similarities
# Out:
# array([[ 0.10209964,  0.09248553, -0.00529486,  0.63144386,  0.02336383,
#          0.09323297,  0.10764793,  0.0699893 ,  0.05817442,  0.06608819]])

# %%
print(cosine_similarities)
# Out:
# [[ 0.10209964  0.09248553 -0.00529486  0.63144386  0.02336383  0.09323297
#    0.10764793  0.0699893   0.05817442  0.06608819]]

# %%
# From above we can see the document in 4th position is the most similar to the query "What is AI?"

most_similar_document = documents[3]
most_similar_document
# Out:
# 'Artificial Intelligence aims to create machines that can think and learn.'

# %% [markdown]
# We can also get is using `np.argmax`

# %%
import numpy as np

documents[np.argmax(cosine_similarities[0])]
# Out:
# 'Artificial Intelligence aims to create machines that can think and learn.'

# %% [markdown]
# ### Create Search Engine function

# %%
def semantic_search_engine(query, embedder_model):
  query_embedding = embedder_model.embed_query(query)
  cos_scores = cosine_similarity([query_embedding], document_embeddings)[0]
  top_result_id = np.argmax(cos_scores)
  return documents[top_result_id]

# %% [markdown]
# ### Try out the function

# %%
new_sentence = 'Tell me about AI'
semantic_search_engine(new_sentence, openai_embed_model)
# Out:
# 'Artificial Intelligence aims to create machines that can think and learn.'

# %%
new_sentence = 'Do you know about the pyramids?'
semantic_search_engine(new_sentence, openai_embed_model)
# Out:
# 'The pyramids of Egypt are historical monuments that have stood for thousands of years.'

# %%
new_sentence = 'How do plants survive?'
semantic_search_engine(new_sentence, openai_embed_model)
# Out:
# 'Photosynthesis is the process by which green plants make food using sunlight.'
